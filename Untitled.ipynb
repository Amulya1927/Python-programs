# %%
name="amulya"
print(name)
# Out:
# amulya

# %%
city="maddulapalli"
print(city)
# Out:
# maddulapalli

# %%
city="jagtial"
print(city[2])
# Out:
# g

# %%
name="amulya"
print(name[3])
# Out:
# l

# %%
name="amulya"
print(name[4:1])

# %%
first="amulya" 
second="nunsavath"
print(first+""+second)
# Out:
# amulyanunsavath

# %%
print("abhi"*2)
# Out:
# abhiabhi

# %%
name="abhi"
print( name.upper())
# Out:
# ABHI

# %%
name="abhi" 
print(name.lower())
# Out:
# abhi
