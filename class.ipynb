# %%
class Car:
    name = "RR"
    color = "Red"
    
car1 = Car
print(car1.name)
print(car1.color)
# Out:
# RR
# Red

# %%
class Student:
    def __init__(self,name,age):
     self .name = name
     self .age = age

s1 = Student("amulya",20)
print(s1.name)
# Out:
# amulya
