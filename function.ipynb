# %%
name="abhitha"
print(name.lower())
# Out:
# abhitha

# %%
s="I like Python"
print( s.replace("Python", "java"))
# Out:
# I like java

# %% [markdown]
# name=input("enter the name")
# print( "welcome",name)

# %%
name=input("Enter the name:")
print( "welcome", name)
# Out:
# Enter the name: abhitha
# welcome abhitha

# %%
p="python"
print(p[::-1])
# Out:
# nohtyp

# %%
name="amulya"
def greet():
    print("Hello", name)
greet()
# Out:
# Hello amulya

# %%
name="ammu"
def ammayi():
    print("Hello", name)
ammayi()
# Out:
# Hello ammu

# %%
def add(a,b,c=0):
    return a+b+c
print(add(10,20,))
print(add(10,20,30))
# Out:
# 30
# 60

# %%
def multiply(a,b):
    return a*b
print(multiply(5,10))
# Out:
# 50

# %%
def add(*numders):
    print(sum(numders))
add(10,20)
add(10,20,30)
add(10,20,30,40)
# Out:
# 30
# 60
# 100

# %%
def stu(*marks):
    print(sum(marks))
stu(20,30)
stu(20,30,40)
stu(20,30,40,50)
# Out:
# 50
# 90
# 140
